# %%
# %matplotlib inline
from matplotlib import pyplot as plt
import cv2
import numpy as np

# %%
img = cv2.imread("/mnt/Data/Documents/Praca_magisterska/dataset/dataset-master/unlabeled/LYMPHOCYTE/_4_7082.jpeg")
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
hsv_img = cv2.cvtColor(img, cv2.COLOR_RGB2HSV)

plt.imshow(img)
plt.show()

# %%
hsv_img[145][145]
# Out:
# array([ 36,   6, 209], dtype=uint8)

# %%
hsv_img[150][100]
# Out:
# array([ 36,   6, 208], dtype=uint8)

# %%
hsv_img[100][150]
# Out:
# array([ 36,   6, 204], dtype=uint8)

# %%
lower_color_mask = np.array([120,70,180])
upper_color_mask = np.array([140,140,240])
mask = cv2.inRange(hsv_img, lower_color_mask, upper_color_mask)

kernel_open = np.ones((10,10))
kernel_close = np.ones((50,50))

mask_open=cv2.morphologyEx(mask,cv2.MORPH_OPEN, kernel_open)
mask_close=cv2.morphologyEx(mask_open,cv2.MORPH_CLOSE, kernel_close)
dilation = cv2.dilate(mask_close, np.ones((20, 20)), iterations = 1)

masked = cv2.bitwise_and(img, img, mask=dilation)
plt.imshow(masked)

# %%
masked.shape
# Out:
# (240, 320, 3)

# %%
mins = [240, 320] # y,x
maxes = [0, 0]
for y in range(masked.shape[0]):
    for x in range(masked.shape[1]):
        if not masked[y][x][0] == 0:
            if y < mins[0]:
                mins[0] = y
            if y > maxes[0]:
                maxes[0] = y
            if x < mins[1]:
                mins[1] = x
            if x > maxes[1]:
                maxes[1] = x
                
(mins, maxes)
# Out:
# ([94, 156], [157, 220])

# %%
mins.reverse()
maxes.reverse()
cv2.rectangle(masked, tuple(mins), tuple(maxes), (0,255,0),3)
plt.imshow(masked)

# %%
bbox = [(mins[0], maxes[1]), maxes, (maxes[0], mins[1]), (mins)]

# %%
bbox
# Out:
# [(156, 157), [220, 157], (220, 94), [156, 94]]

# %%
lower_color_mask = np.array([120,70,200])
upper_color_mask = np.array([140,140,240])
img = load_img("1.jpeg")
masked = mask_color(img, lower_color_mask, upper_color_mask)
detect_bounds(masked)
# Out:
# [(19, 155), (210, 155), (210, 93), (19, 93)]

# %%
os.listdir("/mnt/Data/Documents/Praca_magisterska/dataset/dataset-master/unlabeled")
# Out:
# ['LYMPHOCYTE.csv',
#  'EOSINOPHIL.csv',
#  'NEUTROPHIL',
#  'LYMPHOCYTE',
#  'MONOCYTE.csv',
#  'EOSINOPHIL',
#  'MONOCYTE',
#  'NEUTROPHIL.csv']
